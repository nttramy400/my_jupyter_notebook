# %% [markdown]
# # Covariance

# %% [markdown]
# Lý thuyết
# ![image.png](attachment:image.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# Lib
# ![image.png](attachment:image.png)

# %%
import numpy as np
a = np.array([45,63,36,52,29,33,48,55,72,66])
b = np.array([20,19,16,20,12,14,16,18,20,22])
print (np.cov(a,b))
print (np.cov(a,b)[0][1])
print (sum((a-np.mean(a))*(b-np.mean(b)))/len(a))
# Out:
# [[ 210.32222222   37.85555556]
#  [  37.85555556    9.78888889]]
# 37.8555555556
# 34.07
